# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.tree import plot_tree
from sklearn.tree import export_text
import joblib

# %%
og_df = pd.read_csv('Data/preprocessed_dataset.csv')
df = og_df[["happiness_classification","fear","anger","surprise","sadness","disgust","joy","anticipation"]]
df.head()
# Out:
#   happiness_classification      fear     anger  surprise   sadness   disgust  \
# 0                not-happy  0.044010  0.029340  0.034230  0.031785  0.026895
# 1                not-happy  0.060606  0.028520  0.033868  0.035651  0.024955
# 2                    happy  0.072381  0.049524  0.040000  0.038095  0.034286
# 3                not-happy  0.059840  0.043883  0.019947  0.041223  0.031915
# 4                    happy  0.070225  0.043539  0.036517  0.036517  0.028090
#
#         joy  anticipation
# 0  0.056235      0.100244
# 1  0.057041      0.112299
# 2  0.097143      0.091429
# 3  0.070479      0.093085
# 4  0.081461      0.102528

# %%
le = LabelEncoder()
df["happiness_classification"] = le.fit_transform(df["happiness_classification"])
df["happiness_classification"] = df["happiness_classification"].replace({0: 1, 1: 0})
df.head()
# Out:
# /var/folders/t3/fn5x2gps4wq728lxf9qrv_lm0000gn/T/ipykernel_19952/1102069732.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["happiness_classification"] = le.fit_transform(df["happiness_classification"])
# /var/folders/t3/fn5x2gps4wq728lxf9qrv_lm0000gn/T/ipykernel_19952/1102069732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["happiness_classification"] = df["happiness_classification"].replace({0: 1, 1: 0})
#    happiness_classification      fear     anger  surprise   sadness   disgust  \
# 0                         0  0.044010  0.029340  0.034230  0.031785  0.026895
# 1                         0  0.060606  0.028520  0.033868  0.035651  0.024955
# 2                         1  0.072381  0.049524  0.040000  0.038095  0.034286
# 3                         0  0.059840  0.043883  0.019947  0.041223  0.031915
# 4                         1  0.070225  0.043539  0.036517  0.036517  0.028090
#
#         joy  anticipation
# 0  0.056235      0.100244
# 1  0.057041      0.112299
# 2  0.097143      0.091429
# 3  0.070479      0.093085
# 4  0.081461      0.102528

# %%
X = df.drop(columns=['happiness_classification'])
y = df['happiness_classification']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 5)
print(f"Training features shape: {X_train.shape}")
print(f"Testing features shape: {X_test.shape}")
# Out:
# Training features shape: (736, 7)
# Testing features shape: (185, 7)

# %%
initial_dt = tree.DecisionTreeClassifier(random_state=5)

cv = KFold(n_splits=10, shuffle=True, random_state=5)

def run_cv(model, X, y, cv):

    accuracy_scores = []

    for train, val in cv.split(X, y):

        X_train_fold, X_val_fold = X.iloc[train], X.iloc[val]
        y_train_fold, y_val_fold = y.iloc[train], y.iloc[val]
        model.fit(X_train_fold, y_train_fold)
        y_pred_val_fold = model.predict(X_val_fold)

        accuracy_scores.append(accuracy_score(y_val_fold, y_pred_val_fold))

    average_accuracy_score = np.mean(accuracy_scores)

    return average_accuracy_score

init_average_accuracy = run_cv(initial_dt, X_train, y_train, cv)
print("Average accuracy before hyperparameter tuning: ", init_average_accuracy)

param_grid = {
    'max_depth': [1, 3, 5, 7, 10],
    'min_samples_split': [5, 10, 15, 20, 50],
    'min_samples_leaf':[1, 3, 5, 7, 10]
    } 

grid_search = GridSearchCV(initial_dt, param_grid, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

print("Best hyperparameters: ", grid_search.best_params_)
print("Best accuracy score from hyperparameter tuning ", grid_search.best_score_)

my_dt = tree.DecisionTreeClassifier(random_state=5,max_depth=3,min_samples_leaf=7,min_samples_split=5)
my_dt.fit(X_train, y_train)
y_pred_class = my_dt.predict(X_test)
y_pred_prob = my_dt.predict_proba(X_test)[:,1]

test_accuracy_score = accuracy_score(y_test, y_pred_class)
print("Accuracy on Test:", test_accuracy_score)
test_precision_score = precision_score(y_test, y_pred_class)
print("Precision on Test:", test_precision_score)
test_recall_score = recall_score(y_test, y_pred_class)
print("Recall on Test:", test_recall_score)
test_f1_score = f1_score(y_test, y_pred_class)
print("F1 on Test:", test_f1_score)
roc_auc_result = roc_auc_score(y_test, y_pred_prob)
print("AUC", roc_auc_result)
# Out:
# Average accuracy before hyperparameter tuning:  0.5310810810810811
# Best hyperparameters:  {'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 5}
# Best accuracy score from hyperparameter tuning  0.563939281747501
# Accuracy on Test: 0.5837837837837838
# Precision on Test: 0.5806451612903226
# Recall on Test: 0.41379310344827586
# F1 on Test: 0.4832214765100671
# AUC 0.5802251935256861

# %%
import joblib

# Creating dataset for trading model.
tr_X = og_df[['norm_imports', 'norm_exports']]
tr_y = df['happiness_classification']

tr_X_train, tr_X_test, tr_y_train, tr_y_test = train_test_split(tr_X, tr_y, test_size=0.2, random_state=5)

# Loading the trained model for trade.
tr_dt = joblib.load('Models/trading_tree_clf.pkl')

tr_y_pred_class = tr_dt.predict(tr_X_test)
tr_y_pred_prob = tr_dt.predict_proba(tr_X_test)[:,1]

tr_test_accuracy_score = accuracy_score(tr_y_test, tr_y_pred_class)
print("Accuracy on Test:", tr_test_accuracy_score)
tr_test_precision_score = precision_score(tr_y_test, tr_y_pred_class)
print("Precision on Test:", tr_test_precision_score)
tr_test_recall_score = recall_score(tr_y_test, tr_y_pred_class)
print("Recall on Test:", tr_test_recall_score)
tr_test_f1_score = f1_score(tr_y_test, tr_y_pred_class)
print("F1 on Test:", tr_test_f1_score)
tr_roc_auc_result = roc_auc_score(tr_y_test, tr_y_pred_prob)
print("AUC", tr_roc_auc_result)
# Out:
# Accuracy on Test: 0.7783783783783784
# Precision on Test: 0.75
# Recall on Test: 0.7931034482758621
# F1 on Test: 0.770949720670391
# AUC 0.7932793807178043

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
tr_fpr, tr_tpr, _ = roc_curve(tr_y_test, tr_y_pred_prob)

fig, ax = plt.subplots()
ax.plot(fpr, tpr, label='UNGD Emotions')
ax.plot(tr_fpr, tr_tpr, label='Trading Activity')
ax.plot([0, 1], [0, 1], '--')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve - Decision Trees')
ax.legend()
plt.show()

# %%
r = export_text(my_dt, feature_names=X_train.columns.tolist())
print(r)
# Out:
# |--- joy <= 0.07
# |   |--- disgust <= 0.04
# |   |   |--- fear <= 0.05
# |   |   |   |--- class: 0
# |   |   |--- fear >  0.05
# |   |   |   |--- class: 1
# |   |--- disgust >  0.04
# |   |   |--- disgust <= 0.05
# |   |   |   |--- class: 0
# |   |   |--- disgust >  0.05
# |   |   |   |--- class: 1
# |--- joy >  0.07
# |   |--- anger <= 0.03
# |   |   |--- disgust <= 0.01
# |   |   |   |--- class: 1
# |   |   |--- disgust >  0.01
# |   |   |   |--- class: 0
# |   |--- anger >  0.03
# |   |   |--- anger <= 0.08
# |   |   |   |--- class: 0
# |   |   |--- anger >  0.08
# |   |   |   |--- class: 0

# %%
tr_r = export_text(tr_dt, feature_names=tr_X_train.columns.tolist())
print(tr_r)
# Out:
# |--- norm_exports <= 0.40
# |   |--- norm_imports <= 0.29
# |   |   |--- norm_exports <= 0.03
# |   |   |   |--- class: 0
# |   |   |--- norm_exports >  0.03
# |   |   |   |--- norm_imports <= 0.26
# |   |   |   |   |--- norm_exports <= 0.04
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- norm_exports >  0.04
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- norm_imports >  0.26
# |   |   |   |   |--- class: 1
# |   |--- norm_imports >  0.29
# |   |   |--- norm_exports <= 0.07
# |   |   |   |--- class: 1
# |   |   |--- norm_exports >  0.07
# |   |   |   |--- norm_imports <= 0.66
# |   |   |   |   |--- norm_exports <= 0.17
# |   |   |   |   |   |--- norm_exports <= 0.11
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- norm_exports >  0.11
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- norm_exports >  0.17
# |   |   |   |   |   |--- norm_exports <= 0.20
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- norm_exports >  0.20
# |   |   |   |   |   |   |--- norm_exports <= 0.32
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- norm_exports >  0.32
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- norm_imports >  0.66
# |   |   |   |   |--- class: 0
# |--- norm_exports >  0.40
# |   |--- norm_exports <= 50.46
# |   |   |--- norm_exports <= 9.29
# |   |   |   |--- norm_imports <= 1.26
# |   |   |   |   |--- norm_imports <= 0.84
# |   |   |   |   |   |--- norm_imports <= 0.26
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- norm_imports >  0.26
# |   |   |   |   |   |   |--- norm_exports <= 1.43
# |   |   |   |   |   |   |   |--- norm_imports <= 0.28
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- norm_imports >  0.28
# |   |   |   |   |   |   |   |   |--- norm_exports <= 0.69
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- norm_exports >  0.69
# |   |   |   |   |   |   |   |   |   |--- norm_exports <= 0.74
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_exports >  0.74
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- norm_exports >  1.43
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- norm_imports >  0.84
# |   |   |   |   |   |--- norm_exports <= 1.56
# |   |   |   |   |   |   |--- norm_exports <= 1.41
# |   |   |   |   |   |   |   |--- norm_exports <= 0.68
# |   |   |   |   |   |   |   |   |--- norm_exports <= 0.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- norm_exports >  0.45
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- norm_exports >  0.68
# |   |   |   |   |   |   |   |   |--- norm_exports <= 0.86
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- norm_exports >  0.86
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 1.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  1.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- norm_exports >  1.41
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- norm_exports >  1.56
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- norm_imports >  1.26
# |   |   |   |   |--- norm_exports <= 1.64
# |   |   |   |   |   |--- norm_imports <= 2.25
# |   |   |   |   |   |   |--- norm_exports <= 1.29
# |   |   |   |   |   |   |   |--- norm_imports <= 1.33
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- norm_imports >  1.33
# |   |   |   |   |   |   |   |   |--- norm_exports <= 0.56
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- norm_exports >  0.56
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 1.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  1.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- norm_exports >  1.29
# |   |   |   |   |   |   |   |--- norm_exports <= 1.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- norm_exports >  1.35
# |   |   |   |   |   |   |   |   |--- norm_imports <= 1.43
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- norm_imports >  1.43
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 1.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  1.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- norm_imports >  2.25
# |   |   |   |   |   |   |--- norm_exports <= 1.09
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- norm_exports >  1.09
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- norm_exports >  1.64
# |   |   |   |   |   |--- norm_imports <= 3.57
# |   |   |   |   |   |   |--- norm_exports <= 4.31
# |   |   |   |   |   |   |   |--- norm_exports <= 2.99
# |   |   |   |   |   |   |   |   |--- norm_imports <= 2.03
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 1.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  1.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- norm_imports >  2.03
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 3.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  3.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- norm_exports >  2.99
# |   |   |   |   |   |   |   |   |--- norm_exports <= 3.36
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- norm_exports >  3.36
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- norm_exports >  4.31
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- norm_imports >  3.57
# |   |   |   |   |   |   |--- norm_exports <= 3.16
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- norm_exports >  3.16
# |   |   |   |   |   |   |   |--- norm_imports <= 10.13
# |   |   |   |   |   |   |   |   |--- norm_exports <= 4.46
# |   |   |   |   |   |   |   |   |   |--- norm_imports <= 4.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_imports >  4.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- norm_exports >  4.46
# |   |   |   |   |   |   |   |   |   |--- norm_exports <= 5.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- norm_exports >  5.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- norm_imports >  10.13
# |   |   |   |   |   |   |   |   |--- norm_exports <= 7.25
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- norm_exports >  7.25
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- norm_exports >  9.29
# |   |   |   |--- norm_exports <= 14.61
# |   |   |   |   |--- norm_exports <= 11.26
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- norm_exports >  11.26
# |   |   |   |   |   |--- norm_exports <= 12.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- norm_exports >  12.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- norm_exports >  14.61
# |   |   |   |   |--- norm_imports <= 14.28
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- norm_imports >  14.28
# |   |   |   |   |   |--- norm_exports <= 38.53
# |   |   |   |   |   |   |--- norm_imports <= 17.37
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- norm_imports >  17.37
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- norm_exports >  38.53
# |   |   |   |   |   |   |--- class: 0
# |   |--- norm_exports >  50.46
# |   |   |--- class: 0

# %%
feature_names = X_train.columns.tolist()
plt.figure(figsize=(9, 5))
plot_tree(my_dt, filled=True, feature_names=feature_names, class_names=[str(target) for target in my_dt.classes_], rounded=True, precision=2)
plt.show()

# %%
feature_names = tr_X_train.columns.tolist()
plt.figure(figsize=(9, 5))
plot_tree(tr_dt, filled=True, feature_names=feature_names, class_names=[str(target) for target in my_dt.classes_], rounded=True, precision=2)
plt.show()

# %%
joblib.dump(my_dt, 'Models/emotions_tree_clf.pkl')
# Out:
# ['Models/emotions_tree_clf.pkl']
