# %% [markdown]
# ### Data Exploration

# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import warnings
# warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Data/preprocessed_dataset.csv')

# %%
# show head
df.head()
# Out:
#   happiness_classification  norm_imports  norm_exports      fear     anger  \
# 0                not-happy     13.643921     11.979343  0.044010  0.029340
# 1                not-happy     13.469564     15.552570  0.060606  0.028520
# 2                    happy      6.874739      7.213294  0.072381  0.049524
# 3                not-happy      6.624081      4.183923  0.059840  0.043883
# 4                    happy     12.099429     11.116681  0.070225  0.043539
#
#    surprise   sadness   disgust       joy  anticipation  year   country
# 0  0.034230  0.031785  0.026895  0.056235      0.100244  2005    Mexico
# 1  0.033868  0.035651  0.024955  0.057041      0.112299  2005     Japan
# 2  0.040000  0.038095  0.034286  0.097143      0.091429  2005   Belgium
# 3  0.019947  0.041223  0.031915  0.070479      0.093085  2005  Pakistan
# 4  0.036517  0.036517  0.028090  0.081461      0.102528  2005    France

# %%
df.country.nunique()
# Out:
# 131

# %%
# all columns
print(df.columns.values)

# Quantiles, mean, min, max etc. of the dataset
df.describe()
# Out:
# ['happiness_classification' 'norm_imports' 'norm_exports' 'fear' 'anger'
#  'surprise' 'sadness' 'disgust' 'joy' 'anticipation' 'year' 'country']
#        norm_imports  norm_exports        fear       anger    surprise  \
# count    921.000000    921.000000  921.000000  921.000000  921.000000
# mean       6.456758      5.973886    0.075533    0.051372    0.029842
# std       21.974137     23.279404    0.019541    0.017523    0.008499
# min        0.027052      0.009347    0.021505    0.005025    0.004808
# 25%        0.912420      0.489041    0.062077    0.039352    0.024217
# 50%        1.978003      1.436391    0.074246    0.049784    0.029661
# 75%        4.269860      3.763795    0.087719    0.061644    0.035262
# max      230.704658    241.990881    0.165254    0.126783    0.063679
#
#           sadness     disgust         joy  anticipation         year
# count  921.000000  921.000000  921.000000    921.000000   921.000000
# mean     0.044563    0.027387    0.076754      0.096618  2010.248643
# std      0.015038    0.010827    0.014812      0.014985     2.612691
# min      0.000000    0.000000    0.015038      0.045113  2005.000000
# 25%      0.033898    0.019980    0.067293      0.086667  2008.000000
# 50%      0.043554    0.026506    0.076726      0.096386  2011.000000
# 75%      0.054902    0.034137    0.085995      0.106713  2012.000000
# max      0.100962    0.061275    0.143275      0.146186  2014.000000

# %%
# Describe null values in dataset and where they are
print(df.isnull().sum())
print("")

# Percentage of null values from total column
# Grey source reference: https://www.analyticsvidhya.com/blog/2022/07/step-by-step-exploratory-data-analysis-eda-using-python/
print((df.isnull().sum()/len(df))*100)
# Out:
# happiness_classification    0
# norm_imports                0
# norm_exports                0
# fear                        0
# anger                       0
# surprise                    0
# sadness                     0
# disgust                     0
# joy                         0
# anticipation                0
# year                        0
# country                     0
# dtype: int64
#
# happiness_classification    0.0
# norm_imports                0.0
# norm_exports                0.0
# fear                        0.0
# anger                       0.0
# surprise                    0.0
# sadness                     0.0
# disgust                     0.0
# joy                         0.0
# anticipation                0.0
# year                        0.0
# country                     0.0
# dtype: float64

# %%
# Number of unique values
print(df.nunique())
# Out:
# happiness_classification      2
# norm_imports                921
# norm_exports                921
# fear                        869
# anger                       875
# surprise                    805
# sadness                     843
# disgust                     837
# joy                         847
# anticipation                846
# year                         10
# country                     131
# dtype: int64

# %%
corr_df = df.drop(['happiness_classification', 'year', 'country'], axis=1)
correlation_matrix= corr_df.corr(method='pearson')

# Create a heatmap with conditional formatting
plt.figure(figsize=(8, 6)) 
plt.title("Correlation Matrix of all numerous features")
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='RdBu')

plt.savefig('Figures/corr-matrix.png')

# %%
figure = pd.plotting.scatter_matrix(df, figsize=(14,12))
plt.savefig('Figures/scatter.png')
